# %%
import eda_toolkit as tk

# %%
df = tk.pd.read_csv('customer_churn.csv')

# %%
tk.data_info(df)
# Out:
# (64374, 12)
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
# 5           6   30    Male      41               14             10
# 6           7   47  Female      37               15              9
# 7           8   54  Female      36               11              0
# 8           9   36    Male      20                5             10
# 9          10   65    Male       8                4              2
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# ...

# %%
tk.value_info(df)
# Out:
#  Null Values
#
# CustomerID           0
# Age                  0
# Gender               0
# Tenure               0
# Usage Frequency      0
# Support Calls        0
# Payment Delay        0
# Subscription Type    0
# Contract Length      0
# Total Spend          0
# Last Interaction     0
# Churn                0
# dtype: int64
#
#  Unique Values
#
# Gender                   2
# Churn                    2
# Contract Length          3
# Subscription Type        3
# Support Calls           11
# Last Interaction        30
# Usage Frequency         30
# Payment Delay           31
# Age                     48
# Tenure                  60
# Total Spend            901
# CustomerID           64374
# dtype: int64
#
#  Duplicates
#
# 0

# %%
tk.seperate_dtypes(df)
# Out:
# (       CustomerID  Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
#  0               1   22      25               14              4             27
#  1               2   41      28               28              7             13
#  2               3   47      27               10              2             29
#  3               4   35       9               12              5             17
#  4               5   53      58               24              9              2
#  ...           ...  ...     ...              ...            ...            ...
#  64369       64370   45      33               12              6             21
#  64370       64371   37       6                1              5             22
#  64371       64372   25      39               14              8             30
#  64372       64373   50      18               19              7             22
#  64373       64374   52      45               15              9             25
#
# ...
